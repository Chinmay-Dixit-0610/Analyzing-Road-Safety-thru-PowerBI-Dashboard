# %%
import pandas as pd

# Load the dataset to understand its structure and content
file_path = "Road_Accidents_2017-Annuxure_Tables_23.csv"
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure and content
data.head()
# Out:
#           States/UTs  Sunny/Clear - Total Accidents  \
# 0     Andhra Pradesh                          20090
# 1  Arunachal Pradesh                             60
# 2              Assam                           3423
# 3              Bihar                           3470
# 4       Chhattisgarh                           7103
#
#    Sunny/Clear - Persons Killed  Sunny/Clear - Persons Grievously Injured  \
# 0                          6036                                      4769
# 1                            26                                        41
# 2                          1269                                      2719
# 3                          2087                                      1669
# 4                          2059                                      1155
#
#    Sunny/Clear - Persons Minor Injured  Rainy - Total Accidents  \
# 0                                15886                     1098
# 1                                   31                       48
# ...

# %%
# Check for any missing or inconsistent values in the dataset
data.info()

# Display summary statistics to understand the data distribution
data.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   States/UTs                                  37 non-null     object
#  1   Sunny/Clear - Total Accidents               37 non-null     int64
#  2   Sunny/Clear - Persons Killed                37 non-null     int64
#  3   Sunny/Clear - Persons Grievously Injured    37 non-null     int64
#  4   Sunny/Clear - Persons Minor Injured         37 non-null     int64
#  5   Rainy - Total Accidents                     37 non-null     int64
#  6   Rainy - Persons Killed                      37 non-null     int64
#  7   Rainy - Persons Grievously Injured          37 non-null     int64
#  8   Rainy - Persons Minor Injured               37 non-null     int64
#  9   Foggy & Misty - Total Accidents             37 non-null     int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Grouping data by weather conditions and summing up the accident counts
weather_conditions = ['Sunny/Clear', 'Rainy', 'Foggy & Misty', 'Hail/Sleet', 'Others']
accident_counts = {
    condition: data[f'{condition} - Total Accidents'].sum() for condition in weather_conditions
}
accidents_by_weather = pd.DataFrame(list(accident_counts.items()), columns=['Weather Condition', 'Total Accidents'])

# Plotting the accident counts by weather condition
plt.figure(figsize=(10, 6))
sns.barplot(x='Weather Condition', y='Total Accidents', data=accidents_by_weather)
plt.title('Total Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Total Accidents')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
